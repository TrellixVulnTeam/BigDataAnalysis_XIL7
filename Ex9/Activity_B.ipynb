# %%
import myFunctions as mf
import pandas as pd

# %%
df = pd.read_csv('../bank.csv', sep=';')

# %%
ml = 0.1
df = mf.generateMissingVal(df,ml)
lW,uW = mf.calcIQR(df)

# %%
df.isna().sum()
# Out:
# age          413
# job          455
# marital      428
# education    438
# default      443
# balance      441
# housing      434
# loan         419
# contact      408
# day          412
# month        420
# duration     411
# campaign     402
# pdays        444
# previous     446
# poutcome     427
# y            462
# dtype: int64

# %%
display(mf.showOutliners('age',df,uW,lW,'both'))
# Out:
#        age         job   marital  education default  balance housing loan  \
# 36    78.0     retired  divorced    primary     NaN    229.0     NaN   no
# 129   77.0     retired  divorced        NaN      no   4659.0      no   no
# 166   78.0   housemaid   married  secondary     NaN    499.0     NaN   no
# 199   75.0     retired   married  secondary      no   3771.0     NaN   no
# 412   75.0     retired  divorced   tertiary      no   3810.0     yes   no
# 477   77.0     retired       NaN   tertiary      no   7802.0      no   no
# 573   81.0     retired   married  secondary      no      1.0      no   no
# 633   83.0     retired   married  secondary      no      0.0      no   no
# 688   80.0  management   married    primary      no   6483.0      no   no
# 1126  77.0     retired   married  secondary      no    610.0      no   no
# 1230  75.0     retired       NaN  secondary      no   1341.0      no   no
# 1312  80.0     retired   married  secondary      no   8304.0      no   no
# 1415  75.0     retired  divorced    primary      no    852.0      no   no
# 1422  79.0     retired       NaN  secondary      no   4738.0      no   no
# 1437  77.0     retired   married   tertiary      no      0.0      no   no
# 1949  78.0     retired   married   tertiary      no    226.0      no   no
# 1956  77.0     retired   married    primary      no    680.0      no   no
# 2014  74.0     retired  divorced  secondary      no   4079.0      no   no
# 2070  80.0     retired   married  secondary      no   8304.0      no   no
# 2678  74.0     retired   married  secondary      no    935.0      no   no
# 2848  80.0     retired   married  secondary      no    462.0      no   no
# 2896  80.0     retired   married    primary      no   1548.0     NaN   no
# 3157  75.0         NaN   married  secondary      no   6053.0      no  NaN
# 3193  76.0         NaN  divorced    primary      no     86.0      no   no
# 3202  79.0     retired   married    primary      no      NaN      no   no
# 3205  77.0     retired   married        NaN      no    680.0      no   no
# 3311  87.0     retired   married    primary     NaN      NaN      no   no
# 3360  79.0     retired   married    primary      no    429.0      no   no
# 3495  76.0     retired   married    primary      no   2590.0      no   no
# 3690  80.0   housemaid   married    primary      no      NaN     NaN   no
# 3750  79.0         NaN  divorced    unknown     NaN   2628.0      no   no
# 3786  74.0     retired   married  secondary     NaN    921.0      no   no
# 4047  75.0     retired   married  secondary      no  26452.0      no   no
# 4108  84.0     retired  divorced    primary      no    639.0      no   no
# 4323  83.0     retired  divorced    primary      no      0.0      no   no
# 4388  83.0         NaN  divorced        NaN      no   1097.0      no   no
#
#         contact   day month  duration  campaign  pdays  previous poutcome    y
# 36    telephone  22.0   oct       NaN       1.0   -1.0       0.0  unknown  yes
# 129    cellular  14.0   apr     161.0       1.0   -1.0       0.0  unknown  NaN
# 166   telephone  16.0   NaN      80.0       4.0   -1.0       0.0  unknown   no
# 199   telephone  15.0   apr     185.0       1.0  181.0       2.0  success  NaN
# 412    cellular  16.0   nov     262.0       1.0  183.0       1.0  failure  yes
# 477   telephone   4.0   may     421.0       1.0   92.0       2.0  success  yes
# 573    cellular  19.0   aug      65.0       5.0   -1.0       NaN  unknown   no
# 633    cellular  18.0   mar     140.0      10.0   -1.0       0.0  unknown   no
# 688   telephone  19.0   oct     123.0       1.0   -1.0       0.0  unknown   no
# 1126   cellular  13.0   aug     766.0       3.0   -1.0       0.0  unknown   no
# 1230   cellular  18.0   dec     415.0       7.0   -1.0       0.0  unknown  NaN
# 1312  telephone   9.0   jun     712.0       1.0   64.0      12.0  failure  yes
# 1415   cellular  15.0   mar     341.0       1.0   -1.0       0.0  unknown   no
# 1422        NaN   9.0   jul     151.0       5.0   -1.0       0.0  unknown   no
# 1437   cellular  16.0   oct     847.0       1.0   60.0       1.0  success  yes
# 1949  telephone   NaN   nov     136.0       1.0   -1.0       0.0  unknown   no
# 1956  telephone   NaN   feb     513.0       2.0   89.0       7.0  failure   no
# 2014   cellular  19.0   oct     343.0       3.0   -1.0       0.0      NaN  yes
# 2070  telephone   6.0   NaN     681.0       1.0    NaN       NaN  success   no
# 2678   cellular  26.0   jan     100.0       1.0  104.0       1.0    other   no
# 2848   cellular   7.0   dec     127.0       2.0   -1.0       0.0  unknown   no
# 2896   cellular   6.0   aug     331.0       2.0   -1.0       0.0  unknown   no
# 3157   cellular  11.0   feb     865.0       2.0  190.0       1.0  failure   no
# 3193   cellular  12.0   aug       NaN       1.0   -1.0       0.0  unknown   no
# 3202  telephone  18.0   NaN     326.0       2.0  272.0       2.0  success  yes
# 3205  telephone  27.0   NaN     341.0       4.0   94.0       NaN  failure   no
# 3311   cellular  30.0   oct     144.0       1.0   -1.0       NaN  unknown  yes
# 3360  telephone   8.0   jul    1006.0       2.0   -1.0       0.0  unknown  yes
# 3495  telephone   9.0   feb      68.0      12.0   -1.0       0.0  unknown  NaN
# 3690   cellular   NaN   feb       NaN       1.0  189.0       1.0  failure  yes
# 3750  telephone   8.0   jul     220.0       7.0  450.0       2.0  failure   no
# 3786  telephone  17.0   apr     394.0       NaN   -1.0       NaN      NaN  yes
# 4047  telephone  15.0   jul     219.0       2.0   -1.0       0.0      NaN   no
# 4108  telephone  18.0   may     353.0       3.0   -1.0       0.0  unknown  yes
# 4323  telephone  31.0   may     664.0       1.0   77.0       3.0  success   no
# 4388        NaN   5.0   NaN     181.0       1.0   -1.0       0.0  unknown  yes

# %%
mf.plotOutliners('age',df)
