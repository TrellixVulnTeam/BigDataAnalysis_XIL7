# %%
import myFunctionsOO as mFoo
import pandas as pd

# %%
df = pd.read_csv('../bank.csv',sep=';')
ml = 0.1
myObject = mFoo.myResearch(df)
myObject.generateMissingVal(df,ml)
# Out:
#        age            job  marital  education default  balance housing loan  \
# 0     30.0            NaN  married    primary      no   1787.0      no   no
# 1     33.0       services  married  secondary      no   4789.0     yes  yes
# 2     35.0     management      NaN   tertiary      no   1350.0     yes   no
# 3     30.0     management  married   tertiary      no   1476.0     yes  yes
# 4     59.0    blue-collar  married  secondary      no      0.0     yes   no
# ...    ...            ...      ...        ...     ...      ...     ...  ...
# 4516  33.0       services  married  secondary      no   -333.0     NaN   no
# 4517  57.0  self-employed  married   tertiary     yes  -3313.0     yes  yes
# 4518  57.0     technician  married  secondary      no    295.0      no   no
# 4519  28.0    blue-collar  married  secondary      no   1137.0      no   no
# 4520  44.0   entrepreneur   single   tertiary      no   1136.0     NaN  yes
#
# ...

# %%
lW, uW = myObject.calcIQR(df)

# %%
myObject.showOutliners('age',df,uW,lW,'both')
# Out:
#       age          job   marital  education default  balance housing loan  \
# 36     78      retired  divorced    primary      no      229      no   no
# 129    77      retired  divorced   tertiary      no     4659      no   no
# 166    78    housemaid   married  secondary      no      499      no   no
# 199    75      retired   married  secondary      no     3771      no   no
# 412    75      retired  divorced   tertiary      no     3810     yes   no
# 477    77      retired   married   tertiary      no     7802      no   no
# 573    81      retired   married  secondary      no        1      no   no
# 633    83      retired   married  secondary      no        0      no   no
# 688    80   management   married    primary      no     6483      no   no
# 1126   77      retired   married  secondary      no      610      no   no
# 1230   75      retired  divorced  secondary      no     1341      no   no
# 1312   80      retired   married  secondary      no     8304      no   no
# ...

# %%
myObject.plotOutliners('age',df)
