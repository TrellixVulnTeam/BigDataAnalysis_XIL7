# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

x = np.linspace(-4,4,100)
f1 = 4 * x ** 2
f2 = x**4 - 13 * x ** 2 + 20
plt.plot(f1)
plt.plot(f2)

# %%
fig, ax = plt.subplots()
x = np.linspace(0,100,500)
y = np.sin(2*np.pi*x/100) #change divdion value
ax.plot(x,y)
